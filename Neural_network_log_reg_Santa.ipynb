# %% [markdown]
# # Lab: building your first neural network

# %% [markdown]
# Congratulations, you made it to your first lab! In this lab, you'll practice everything you have learned during the lecture. We know there is quite a bit of math involved, but don't worry! Using Python and trying things out yourself will actually make a lot of things much more clear! Before we start, let's import some necessary libraries so we can import our data.

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import numpy as np
import os

# %%
train_data_dir = 'santa/data/train'
test_data_dir = 'santa/data/validation'
nb_train_samples = 790
nb_validation_samples = 132

# %%
test_generator = ImageDataGenerator().flow_from_directory(
        test_data_dir, 
        target_size=(200, 200), batch_size=132)
# Out:
# Found 132 images belonging to 2 classes.

# %%
train_generator = ImageDataGenerator().flow_from_directory(
        train_data_dir, 
        target_size=(200, 200), batch_size=790)
# Out:
# Found 790 images belonging to 2 classes.

# %%
train_images, train_labels = next(train_generator)

# %%
test_images, test_labels = next(test_generator)

# %%
train_generator.class_indices
# Out:
# {'not_santa': 0, 'santa': 1}

# %%
np.shape(train_images)
# Out:
# (790, 200, 200, 3)

# %%
array_to_img(test_images[102])
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x10222B630>

# %%
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255

# %%
test_lab = test_labels[0]
train_lab = train_labels[0]

# %%
img_val = train_images[:200]
partial_img_train  = train_images[200:]
label_val = train_lab[:200]
partial_label_train = train_lab[200:]
